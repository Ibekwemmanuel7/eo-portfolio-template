# %% [markdown]
# # Module 0.4: a professional git history
# Git runs in a terminal, so this notebook uses shell cells (the `!` prefix). Codespaces gives you a full terminal; here you can rehearse the commands.

# %%
# !git --version

# %% [markdown]
# ### Rehearse the core loop in a scratch repo

# %%
# %cd /tmp
# !rm -rf gitdemo && mkdir gitdemo && cd gitdemo && git init -q && git config user.email you@x.com && git config user.name You && echo '# demo' > README.md && git add README.md && git commit -q -m 'feat: initial commit' && git log --oneline

# %% [markdown]
# ### Your turn
# 1. In your `eo-portfolio` repo, practise a branch-and-pull-request workflow with clear, conventional commit messages.
# 2. Add a `.gitignore`, protect `main`, and let CI run on each push.
# 3. This lab is best done in Codespaces or a local terminal rather than Colab.
