# %% [markdown]
# # Module 11: MLOps and cloud deployment
# Starter scaffold for Module 11.

# %% [markdown]
# ### Install this lab's extras

# %%
# !pip install -q mlflow

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1. Package the pipeline, add CI, and deploy on a cloud VM or serverless with object storage.
# 2. Add monitoring and a scheduled run; document costs and how you stay within free tiers.

# %%
# TODO: build this lab following the module. Commit your work to eo-portfolio.
