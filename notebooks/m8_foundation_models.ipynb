# %% [markdown]
# # Module 8: geospatial foundation models
# Starter scaffold for Module 8.

# %% [markdown]
# ### Install this lab's extras

# %%
# !pip install -q terratorch torchgeo

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1. Fine-tune Prithvi-EO-2.0 with TerraTorch on the Module 7 burn-scar dataset; run a frozen-backbone linear probe.
# 2. Add Clay or TerraMind, and the AlphaEarth embeddings route via Earth Engine.
# 3. Produce one benchmark table: U-Net vs foundation models vs embeddings, on full and 10% labels, with a cost column. GPU required.

# %%
# TODO: build this lab following the module. Commit your work to eo-portfolio.
