# %% [markdown]
# # Module 10: wildfire system end to end
# Starter scaffold for Module 10.

# %% [markdown]
# ### Install this lab's extras

# %%
# !pip install -q rioxarray odc-stac

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1. Chain detection to damage: hotspot in, cloud-free composite, burn map, report out.
# 2. Containerize and schedule it; write to object storage; expose a small live demo map.

# %%
# TODO: build this lab following the module. Commit your work to eo-portfolio.
