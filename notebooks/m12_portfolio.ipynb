# %% [markdown]
# # Module 12: portfolio and job search
# Starter scaffold for Module 12.

# %% [markdown]
# ### Install this lab's extras

# %%
# !pip install -q

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1. Polish the eo-portfolio README selling four projects, three write-ups, and a live demo.
# 2. Record two-minute explainers; whiteboard two system designs; run the interview bank; track applications.

# %%
# TODO: build this lab following the module. Commit your work to eo-portfolio.
